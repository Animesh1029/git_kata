# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

titanic = pd.read_csv("data/titanic.csv", sep=";")
print(titanic.columns)
# Out:
# Index(['Table 1'], dtype='str')

# %%
import pandas as pd

titanic = pd.read_csv("data/titanic.csv", sep=";")

print(titanic.head())
print(titanic.columns)
# Out:
#                                                                                                                                                     Table 1
# pclass survived name                                 sex    age    sibsp parch ticket fare     cabin   embarked boat body                         home.dest
# 1      1        Allen, Miss. Elisabeth Walton        female 29.0   0     0     24160  211.3375 B5      S        2    nan                       St Louis, MO
#                 Allison, Master. Hudson Trevor       male   0.9167 1     2     113781 151.55   C22 C26 S        11   nan    Montreal, PQ / Chesterville, ON
#        0        Allison, Miss. Helen Loraine         female 2.0    1     2     113781 151.55   C22 C26 S        nan  nan    Montreal, PQ / Chesterville, ON
#                 Allison, Mr. Hudson Joshua Creighton male   30.0   1     2     113781 151.55   C22 C26 S        nan  135.0  Montreal, PQ / Chesterville, ON
# Index(['Table 1'], dtype='str')

# %%
with open("data/titanic.csv", "r", encoding="utf-8") as f:
    for _ in range(5):
        print(repr(f.readline()))
# Out:
# 'Table 1\n'
# 'pclass;survived;name;sex;age;sibsp;parch;ticket;fare;cabin;embarked;boat;body;home.dest\n'
# '1;1;Allen, Miss. Elisabeth Walton;female;29.0;0;0;24160;211.3375;B5;S;2;;St Louis, MO\n'
# '1;1;Allison, Master. Hudson Trevor;male;0.9167;1;2;113781;151.55;C22 C26;S;11;;Montreal, PQ / Chesterville, ON\n'
# '1;0;Allison, Miss. Helen Loraine;female;2.0;1;2;113781;151.55;C22 C26;S;;;Montreal, PQ / Chesterville, ON\n'

# %%
print(titanic[:10])
# Out:
#                                                                                                                                                                Table 1
# pclass survived name                                            sex    age    sibsp parch ticket fare     cabin   embarked boat body                         home.dest
# 1      1        Allen, Miss. Elisabeth Walton                   female 29.0   0     0     24160  211.3375 B5      S        2    nan                       St Louis, MO
#                 Allison, Master. Hudson Trevor                  male   0.9167 1     2     113781 151.55   C22 C26 S        11   nan    Montreal, PQ / Chesterville, ON
#        0        Allison, Miss. Helen Loraine                    female 2.0    1     2     113781 151.55   C22 C26 S        nan  nan    Montreal, PQ / Chesterville, ON
# ...

# %%
import pandas as pd

titanic = pd.read_csv("data/titanic.csv", sep=";", header=1)
print(titanic.columns)
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

titanic["pclass"].value_counts().plot(kind="bar")
plt.title("Passenger Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
import pandas as pd

def load_data():
    titanic = pd.read_csv("data/titanic.csv", sep=";", header=1)
    return titanic

# %%
from utils import load_data
import matplotlib.pyplot as plt

titanic = pd.read_csv("data/titanic.csv", sep=";", header=1)

titanic["age"].plot(kind="hist", bins=20)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[17], line 4
#       1 from utils import load_data
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 titanic = pd.read_csv("data/titanic.csv", sep=r"\s{2,}", engine="python", skiprows=1)
#       5
#       6 titanic["age"].plot(kind="hist", bins=20)
#       7
#
# ...

# %%
print(titanic[:10])
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...
