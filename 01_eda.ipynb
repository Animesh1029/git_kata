# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from utils import load_data
titanic = load_data("/Users/diren/Documents/git_kata/data/titanic.csv")

# %%
print(titanic[:10])
# Out:
# [{'Table 1': 'pclass;survived;name;sex;age;sibsp;parch;ticket;fare;cabin;embarked;boat;body;home.dest'}, {'Table 1': '1;1;Allen'}, {'Table 1': '1;1;Allison'}, {'Table 1': '1;0;Allison'}, {'Table 1': '1;0;Allison'}, {'Table 1': '1;0;Allison'}, {'Table 1': '1;1;Anderson'}, {'Table 1': '1;1;Andrews'}, {'Table 1': '1;0;Andrews'}, {'Table 1': '1;1;Appleton'}]
